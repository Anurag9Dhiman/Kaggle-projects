# %%
import sys
import pandas
import numpy
import sklearn
import keras


print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pandas.__version__))
print('Numpy: {}'.format(numpy.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Keras: {}'.format(keras.__version__))
# Out:
# Python: 3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]
# Pandas: 1.3.3
# Numpy: 1.20.3
# Sklearn: 0.24.2
# Keras: 2.6.0

# %%
import pandas as pd
import numpy as np

#importing the uci pima indians diabetes system

names = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin',
        'BMI','DiabetesPedigreeFunction','Age','Outcome']
df = pd.read_csv('diabetes.csv')

# %%
#Describe the dataset
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df[df['Glucose'] == 0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
#preprocess the data, mark zero values as NaN and drop
columns = ['Glucose','BloodPressure','SkinThickness','Insulin',
        'BMI']

for col in columns:
    df[col].replace(0, np.NaN, inplace = True)
    
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
#Drop rows with missing values
df.dropna(inplace =True)

# summarize the number of rows and columns in df
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# ...

# %%
#converting datframe to  numpy array
dataset = df.values
print(dataset)
print(dataset.shape)
# Out:
# [[  1.     89.     66.    ...   0.167  21.      0.   ]
#  [  0.    137.     40.    ...   2.288  33.      1.   ]
#  [  3.     78.     50.    ...   0.248  26.      1.   ]
#  ...
#  [  2.     88.     58.    ...   0.766  22.      0.   ]
#  [ 10.    101.     76.    ...   0.171  63.      0.   ]
#  [  5.    121.     72.    ...   0.245  30.      0.   ]]
# (392, 9)

# %%
#split into input (X) and an output (Y)

X = dataset[:, 0:8]
Y = dataset[:, 8].astype(int)

# %%
print(X.shape)
print(Y.shape)
print(X[:5])
print(Y[:5])
# Out:
# (392, 8)
# (392,)
# [[1.000e+00 8.900e+01 6.600e+01 2.300e+01 9.400e+01 2.810e+01 1.670e-01
#   2.100e+01]
#  [0.000e+00 1.370e+02 4.000e+01 3.500e+01 1.680e+02 4.310e+01 2.288e+00
#   3.300e+01]
#  [3.000e+00 7.800e+01 5.000e+01 3.200e+01 8.800e+01 3.100e+01 2.480e-01
#   2.600e+01]
#  [2.000e+00 1.970e+02 7.000e+01 4.500e+01 5.430e+02 3.050e+01 1.580e-01
#   5.300e+01]
#  [1.000e+00 1.890e+02 6.000e+01 2.300e+01 8.460e+02 3.010e+01 3.980e-01
#   5.900e+01]]
# [0 1 1 1 1]

# %%
#Normalize the data using sklearn StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)

# %%
print(scaler)
# Out:
# StandardScaler()

# %%
# Transform and display the training data
X_standardized = scaler.transform(X)

data = pd.DataFrame(X_standardized)
data.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02
# mean  -4.021726e-17  3.129583e-17 -4.641624e-16  1.042250e-16  6.485742e-17
# std    1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00
# min   -1.029213e+00 -2.161731e+00 -3.739001e+00 -2.108484e+00 -1.196867e+00
# 25%   -7.174265e-01 -7.665958e-01 -6.941640e-01 -7.755315e-01 -6.681786e-01
# 50%   -4.056403e-01 -1.176959e-01 -5.314565e-02 -1.384444e-02 -2.574448e-01
# 75%    5.297185e-01  6.609841e-01  5.878727e-01  7.478426e-01  2.859877e-01
# max    4.271153e+00  2.445459e+00  3.151946e+00  3.223325e+00  5.812990e+00
#
#                   5             6             7
# count  3.920000e+02  3.920000e+02  3.920000e+02
# mean   1.543550e-16  1.897575e-17  1.028089e-16
# std    1.001278e+00  1.001278e+00  1.001278e+00
# min   -2.120941e+00 -1.269525e+00 -9.682991e-01
# ...

# %%
# impoting necessary packages

from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %%
# Start defining the model
def create_model():
    #create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dense(4, input_dim = 8, kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dense(1, activation = 'sigmoid'))
    
    #compile the model
    adam = Adam(lr = 0.01)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model
model = create_model()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 8)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# ...
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Anurag Dhiman\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# importing necessary packages

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

#define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model():
    #create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dense(4, input_dim = 8, kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dense(1, activation = 'sigmoid'))
    
    #compile the model
    adam = Adam(lr = 0.01)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

#create the model
model = KerasClassifier(build_fn = create_model, verbose = 1)

#defining the grid search parameters
batch_size = [10, 20, 40]
epochs = [10, 50, 100]

#making a dictionary of the grid serach parameters
param_grid = dict(batch_size = batch_size, epochs = epochs)

#build and fit the GridSerachCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(n_splits=3,random_state = seed, shuffle = True), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# C:\Users\Anurag Dhiman\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 27/27 [==============================] - 1s 2ms/step - loss: 0.6399 - accuracy: 0.6628
# Epoch 2/10
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5129 - accuracy: 0.6858
# Epoch 3/10
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.6858
# Epoch 4/10
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4763 - accuracy: 0.6858
# Epoch 5/10
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4675 - accuracy: 0.7280
# Epoch 6/10
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7969
# Epoch 7/10
# ...

# %%
#import necassary packages
from keras.layers import Dropout

#define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(learn_rate, dropout_rate):
    #create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, input_dim = 8, kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation = 'sigmoid'))
    
    #compile the model
    adam = Adam(learning_rate = learn_rate)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

#create the model
model = KerasClassifier(build_fn = create_model,epochs = 50, batch_size = 10, verbose = 0)

#defining the grid search parameters
learn_rate = [0.001, 0.01, 0.1]
dropout_rate = [0.0, 0.1, 0.2]

#making a dictionary of the grid serach parameters
param_grid = dict(learn_rate = learn_rate, dropout_rate = dropout_rate)

#build and fit the GridSerachCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(n_splits=3,random_state = seed, shuffle = True), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, params))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 1/3; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.740 total time=   2.8s
# [CV 2/3; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 2/3; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.771 total time=   3.3s
# [CV 3/3; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 3/3; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.785 total time=   2.9s
# [CV 1/3; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 1/3; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.733 total time=   3.0s
# [CV 2/3; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 2/3; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.794 total time=   2.5s
# [CV 3/3; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# ...

# %%
#import necassary packages
from keras.layers import Dropout

#define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(activation, init):
    #create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer = init,activation = activation))
    model.add(Dense(4, input_dim = 8, kernel_initializer = init,activation = activation))
    model.add(Dense(1, activation = 'sigmoid'))
    
    #compile the model
    adam = Adam(learning_rate = 0.01)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

#create the model
model = KerasClassifier(build_fn = create_model,epochs = 50, batch_size = 10, verbose = 0)

#defining the grid search parameters
activation = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

#making a dictionary of the grid serach parameters
param_grid = dict(activation = activation, init = init)


#build and fit the GridSerachCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(n_splits=3,random_state = seed, shuffle = True), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, params))
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV 1/3; 1/12] START activation=softmax, init=uniform...........................
# [CV 1/3; 1/12] END activation=softmax, init=uniform;, score=0.733 total time=   2.6s
# [CV 2/3; 1/12] START activation=softmax, init=uniform...........................
# [CV 2/3; 1/12] END activation=softmax, init=uniform;, score=0.756 total time=   2.7s
# [CV 3/3; 1/12] START activation=softmax, init=uniform...........................
# [CV 3/3; 1/12] END activation=softmax, init=uniform;, score=0.762 total time=   2.6s
# [CV 1/3; 2/12] START activation=softmax, init=normal............................
# [CV 1/3; 2/12] END activation=softmax, init=normal;, score=0.763 total time=   2.5s
# [CV 2/3; 2/12] START activation=softmax, init=normal............................
# [CV 2/3; 2/12] END activation=softmax, init=normal;, score=0.771 total time=   2.8s
# [CV 3/3; 2/12] START activation=softmax, init=normal............................
# ...

# %%
#import necassary packages
from keras.layers import Dropout

#define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(neuron1, neuron2):
    #create model
    model = Sequential()
    model.add(Dense(neuron1, input_dim = 8, kernel_initializer = 'uniform',activation = 'linear'))
    model.add(Dense(neuron2, input_dim = neuron1, kernel_initializer = 'uniform',activation = 'linear'))
    model.add(Dense(1, activation = 'sigmoid'))
    
    #compile the model
    adam = Adam(learning_rate = 0.01)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

#create the model
model = KerasClassifier(build_fn = create_model,epochs = 50, batch_size = 10, verbose = 0)

#defining the grid search parameters
neuron1 = [4, 8, 16]
neuron2 = [2, 4, 8]


#making a dictionary of the grid serach parameters
param_grid = dict(neuron1 = neuron1, neuron2 = neuron2)


#build and fit the GridSerachCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(n_splits=3,random_state = seed, shuffle = True), refit = True, verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, params))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/3; 1/9] END .........neuron1=4, neuron2=2;, score=0.748 total time=   3.1s
# [CV 2/3; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/3; 1/9] END .........neuron1=4, neuron2=2;, score=0.802 total time=   2.5s
# [CV 3/3; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/3; 1/9] END .........neuron1=4, neuron2=2;, score=0.777 total time=   2.5s
# [CV 1/3; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/3; 2/9] END .........neuron1=4, neuron2=4;, score=0.771 total time=   2.5s
# [CV 2/3; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/3; 2/9] END .........neuron1=4, neuron2=4;, score=0.794 total time=   2.7s
# [CV 3/3; 2/9] START neuron1=4, neuron2=4........................................
# ...

# %%
# generate predictions with optimal hyperparameters
y_pred = grid.predict(X_standardized)

# %%
print(y_pred.shape)
# Out:
# (392, 1)

# %%
print(y_pred[:5])
# Out:
# [[0]
#  [1]
#  [0]
#  [1]
#  [1]]

# %%
# Generate a classification report
from sklearn.metrics import classification_report, accuracy_score

print(accuracy_score(Y,y_pred))
print(classification_report(Y,y_pred))
# Out:
# 0.7882653061224489
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       262
#            1       0.74      0.56      0.64       130
#
#     accuracy                           0.79       392
#    macro avg       0.77      0.73      0.74       392
# weighted avg       0.78      0.79      0.78       392

# %%
#example datapoint
example = df.iloc[100]
print(example)
# Out:
# Pregnancies                  1.000
# Glucose                     96.000
# BloodPressure               64.000
# SkinThickness               27.000
# Insulin                     87.000
# BMI                         33.200
# DiabetesPedigreeFunction     0.289
# Age                         21.000
# Outcome                      0.000
# Name: 208, dtype: float64

# %%
# making a prediction using our optimized deep neural network
prediction = grid.predict(X_standardized[100].reshape(1,-1))
print(prediction)
# Out:
# [[0]]
